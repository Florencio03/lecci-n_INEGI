# %%
import json
import sqlite3 as sql
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import json  
plt.style.use('fast')

# %%
#2fa09423-56ad-0077-93c3-406e97234944   ---> my TOKEN 
url='https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000002/es/0700/false/BISE/2.0/2fa09423-56ad-0077-93c3-406e97234944?type=json'
respuesta = requests.get(url)
respuesta.status_code
# Out:
# 200

# %%
url='https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000002/es/0700/false/BISE/2.0/2fa09423-56ad-0077-93c3-406e97234944?type=json'
respuesta = requests.post(url)
#respuesta.status_code
print(respuesta.url)
# Out:
# https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000002/es/0700/false/BISE/2.0/2fa09423-56ad-0077-93c3-406e97234944?type=json

# %%
url='https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000002/es/0700/false/BISE/2.0/2fa09423-56ad-0077-93c3-406e97234944?type=json'
respuesta = requests.get(url)
if respuesta.status_code == 200:
    #print(respuesta.content)
    contenido = json.loads(respuesta.content)
contenido
# Out:
# {'Header': {'Name': 'Datos compactos BISE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '1002000002',
#    'FREQ': '7',
#    'TOPIC': '123',
#    'UNIT': '96',
#    'UNIT_MULT': '',
#    'NOTE': '1398',
#    'SOURCE': '2,3,343,487,781,1668,1669,1670,1671,1672,1677,1678,1679,3001',
#    'LASTUPDATE': '25/05/2022',
#    'STATUS': '3',
#    'OBSERVATIONS': [{'TIME_PERIOD': '1910',
#      'OBS_VALUE': '7504471.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1921',
#      'OBS_VALUE': '7003785.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1930',
#      'OBS_VALUE': '8119004.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1940',
#      'OBS_VALUE': '9695787.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1950',
#      'OBS_VALUE': '12696935.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1960',
#      'OBS_VALUE': '17415320.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1970',
#      'OBS_VALUE': '24065614.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1980',
#      'OBS_VALUE': '33039307.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1990',
#      'OBS_VALUE': '39893969.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '1995',
#      'OBS_VALUE': '44900499.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '422,425',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '2000',
#      'OBS_VALUE': '47592253.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '9,425',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '2005',
#      'OBS_VALUE': '50249955.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '49,425',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '2010',
#      'OBS_VALUE': '54855231.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '115,425',
#      'COBER_GEO': '0700'},
#     {'TIME_PERIOD': '2020',
#      'OBS_VALUE': '61473390.00000000000000000000',
#      'OBS_EXCEPTION': None,
#      'OBS_STATUS': '3',
#      'OBS_SOURCE': '',
#      'OBS_NOTE': '',
#      'COBER_GEO': '0700'}]}]}

# %%
contenido['Series']
# Out:
# [{'INDICADOR': '1002000002',
#   'FREQ': '7',
#   'TOPIC': '123',
#   'UNIT': '96',
#   'UNIT_MULT': '',
#   'NOTE': '1398',
#   'SOURCE': '2,3,343,487,781,1668,1669,1670,1671,1672,1677,1678,1679,3001',
#   'LASTUPDATE': '25/05/2022',
#   'STATUS': '3',
#   'OBSERVATIONS': [{'TIME_PERIOD': '1910',
#     'OBS_VALUE': '7504471.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1921',
#     'OBS_VALUE': '7003785.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1930',
#     'OBS_VALUE': '8119004.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1940',
#     'OBS_VALUE': '9695787.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1950',
#     'OBS_VALUE': '12696935.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1960',
#     'OBS_VALUE': '17415320.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1970',
#     'OBS_VALUE': '24065614.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1980',
#     'OBS_VALUE': '33039307.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1990',
#     'OBS_VALUE': '39893969.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '1995',
#     'OBS_VALUE': '44900499.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '422,425',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '2000',
#     'OBS_VALUE': '47592253.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '9,425',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '2005',
#     'OBS_VALUE': '50249955.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '49,425',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '2010',
#     'OBS_VALUE': '54855231.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '115,425',
#     'COBER_GEO': '0700'},
#    {'TIME_PERIOD': '2020',
#     'OBS_VALUE': '61473390.00000000000000000000',
#     'OBS_EXCEPTION': None,
#     'OBS_STATUS': '3',
#     'OBS_SOURCE': '',
#     'OBS_NOTE': '',
#     'COBER_GEO': '0700'}]}]

# %%
datos_hombres = contenido['Series'][0]['OBSERVATIONS']

# %%
datos_hombres
# Out:
# [{'TIME_PERIOD': '1910',
#   'OBS_VALUE': '7504471.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1921',
#   'OBS_VALUE': '7003785.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1930',
#   'OBS_VALUE': '8119004.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1940',
#   'OBS_VALUE': '9695787.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1950',
#   'OBS_VALUE': '12696935.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1960',
#   'OBS_VALUE': '17415320.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1970',
#   'OBS_VALUE': '24065614.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1980',
#   'OBS_VALUE': '33039307.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1990',
#   'OBS_VALUE': '39893969.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '1995',
#   'OBS_VALUE': '44900499.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '422,425',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '2000',
#   'OBS_VALUE': '47592253.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '9,425',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '2005',
#   'OBS_VALUE': '50249955.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '49,425',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '2010',
#   'OBS_VALUE': '54855231.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '115,425',
#   'COBER_GEO': '0700'},
#  {'TIME_PERIOD': '2020',
#   'OBS_VALUE': '61473390.00000000000000000000',
#   'OBS_EXCEPTION': None,
#   'OBS_STATUS': '3',
#   'OBS_SOURCE': '',
#   'OBS_NOTE': '',
#   'COBER_GEO': '0700'}]

# %%
payload = {'page':2, 'count':25}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "count": "25",
#     "page": "2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.2",
#     "X-Amzn-Trace-Id": "Root=1-655ea8e6-4188261e78755a147c689d74"
#   },
#   "origin": "189.172.209.210",
#   "url": "https://httpbin.org/get?page=2&count=25"
# }
